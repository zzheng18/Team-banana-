# %%
import pandas as pd
from bs4 import BeautifulSoup 
from selenium import webdriver
import lxml
import lxml.html.soupparser
#from IPython.display import HTML

# %%
webdriver_path = '/Users/zzh/Desktop/chromedriver'
# webdriver_path = r'C:\Users\spy61\Desktop\webscraper\chromedriver.exe'  # your filepath here
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')

# %%
driver = webdriver.Chrome(executable_path=webdriver_path, options=options)
threaddriver = webdriver.Chrome(executable_path=webdriver_path, options=options)
# Download html with Selenium
baseUrl = 'https://community.byte.co'
pageUrl = baseUrl + '/latest'
driver.get(pageUrl)

# %%
pageUrl
# Out:
# 'https://community.byte.co/latest'

# %%
# Parse html with beautifulSoup
soup = BeautifulSoup(driver.page_source,'lxml')

# %%
post_links = []

# get the initial height of web page
lastHeight = driver.execute_script("return document.body.scrollHeight")

# the while loop is to check whether you reach the very bottom of the webpage
while True:
    # tell selenium to scroll down to the current bottom of webpage
    driver.execute_script("window.scrollTo(0, 1080)")
    # change number here to decide how much to go through
    
    # To the bottom
    # driver.execute_script("window.scrollTo(arguments[0], document.body.scrollHeight);",lastHeight)
    
    # Parse html with beautifulSoup
    soup = BeautifulSoup(driver.page_source,'lxml')
    # locate the html section with posts
    body = soup.find('body')
    main_outlet = body.find('div',{'class':"container list-container"})

    # get all hyperlinks of post
    all_a = main_outlet.findAll('a',{'class':'title raw-link raw-topic-link'})
    for a in all_a:
        post_link = a.get('href')
        post_links.append(post_link)
    
    # calculate the new height of webpage
    newHeight = driver.execute_script("return document.body.scrollHeight")
    
    if newHeight == lastHeight:
        break
    
    lastHeight = newHeight

# %%
post_links
# Out:
# ['/t/tip-external-editing-for-near-perfect-audio-loops/39519',
#  '/t/the-byte-house/57157',
#  '/t/our-basement/56426',
#  '/t/to-my-og-s/57143',
#  '/t/tiktokers-on-byte/57217',
#  '/t/byte-con-locations/57032',
#  '/t/write-a-haiku-for-a-movie-and-you-have-to-guess-it/27042',
#  '/t/someone-be-proud-pls/57133',
#  '/t/favorite-pop-songs-of-2020/57203',
#  '/t/customisable-recording-limits/57225',
#  '/t/featured-sounds/57221',
#  '/t/1-year-anniversary-on-the-forums/53582',
#  '/t/hi-im-dylan-tate/53903',
#  '/t/text-feature-glitch-my-texts-were-out-of-place/57198',
#  '/t/how-does-byte-handle-ads/57209',
#  '/t/following-doesnt-hold-place-when-you-come-out-of-the-app/57218',
#  '/t/gen-z-on-byte/57200',
#  '/t/best-byte-name-debate-below/57183',
#  '/t/i-found-a-cool-app/57216',
#  '/t/why-every-byter-should-have-a-podcast/57164',
#  '/t/i-have-the-keys-stats-posted/57175',
#  '/t/creating-content-while-depressed/57047',
#  '/t/the-reason-i-dont-go-on-byte-that-much/57210',
#  '/t/official-sandwich-for-byte/57167',
#  '/t/the-sound-feature-isnt-working-for-me/57173',
#  '/t/byte-beats-vs-sounds/57188',
#  '/t/dont-ignore-android-when-developing-byte/55927',
#  '/t/happy-birthday-to-convincinghorse/57176',
#  '/t/best-byte-loop-contest-top-ten-loopforginger/57156',
#  '/t/feeling-silly-i-still-cant-use-sounds/57191']

# %%
# titles = soup.find_all('span', {'class':'link-top-line'})
# urls = []
# for title in titles:
#     t = title.find('a', {'class':'title raw-link raw-topic-link'})
#     urls.append(t['href'])

# %%
# urls

# %%
titles = []
cats = []
names = []
likes = []
posts = []
dates = []
for url in post_links:
    threadUrl = baseUrl + url
    threaddriver.get(threadUrl)
    soup = BeautifulSoup(threaddriver.page_source, 'lxml')
    # get title
    title = soup.find('a', {'class': 'fancy-title'}).getText().strip()
    titles.append(title)
    # get catagory
    cat_class = soup.find('div', {'class': 'title-wrapper'})
    cat = cat_class.find('span', {'class': 'category-name'}).getText()
    cats.append(cat)
    # get host name / name followed by title if has title 
    name = soup.find('div',{'class':'names trigger-user-card'}).getText()
    names.append(name)
    # get host likes
    like = soup.find('div', {'class': 'double-button'}).getText()
    likes.append(like)
    # get host posts
    post = soup.find('div',{'class':'cooked'}).getText().strip()
    posts.append(post)
    # get host dates
    date = soup.find('div', {'class': 'post-info post-date'}).getText()
    dates.append(date)
    # get info for replies and append
    for reply in soup.findAll('div',{'class':'topic-post clearfix regular'}):
        names.append(reply.find('div',{'class':'names trigger-user-card'}).getText())
        posts.append(reply.find('div',{'class':'cooked'}).getText())
        dates.append(reply.find('div',{'class':'post-info post-date'}).getText())
        likes.append(reply.find('div',{'class':'double-button'}).getText())
        titles.append(title)
        cats.append(cat)
    # get info for replies from topic host and append    
    for reply in soup.findAll('div',{'class':'topic-post clearfix topic-owner regular'}):
        names.append(reply.find('div',{'class':'names trigger-user-card'}).getText())
        posts.append(reply.find('div',{'class':'cooked'}).getText())
        dates.append(reply.find('div',{'class':'post-info post-date'}).getText())
        likes.append(reply.find('div',{'class':'double-button'}).getText())
        titles.append(title)
        cats.append(cat)

# %%
posts_dict = {}
posts_dict['title'] = titles
posts_dict['catagory'] = cats
posts_dict['name'] = names
posts_dict['likes'] = likes
posts_dict['content'] = posts
posts_dict['date'] = dates 
posts_dict
# Out:
# {'title': ['Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'Tip: External editing for near-perfect audio loops',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'The Byte House',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'Our basement',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'To My OG’s',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Tiktokers on byte',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Byte con locations',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Write a haiku for a movie and you have to guess it',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Someone be proud pls',
#   'Favorite Pop Songs of 2020',
#   'Favorite Pop Songs of 2020',
#   'Favorite Pop Songs of 2020',
#   'Favorite Pop Songs of 2020',
#   'Favorite Pop Songs of 2020',
#   'Favorite Pop Songs of 2020',
#   'Favorite Pop Songs of 2020',
#   'Favorite Pop Songs of 2020',
#   'Favorite Pop Songs of 2020',
#   'Customisable Recording Limits?',
#   'Customisable Recording Limits?',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   'Featured Sounds',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   '1 year anniversary on the forums!',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Hi, im dylan tate',
#   'Text feature glitch (my texts were out of place)',
#   'Text feature glitch (my texts were out of place)',
#   'Text feature glitch (my texts were out of place)',
#   'Text feature glitch (my texts were out of place)',
#   'Text feature glitch (my texts were out of place)',
#   'How does byte handle ads?',
#   'How does byte handle ads?',
#   'How does byte handle ads?',
#   'How does byte handle ads?',
#   'How does byte handle ads?',
#   'How does byte handle ads?',
#   'How does byte handle ads?',
#   'How does byte handle ads?',
#   '‘Following’ doesn’t hold place when you come out of the app',
#   '‘Following’ doesn’t hold place when you come out of the app',
#   'Gen Z on Byte',
#   'Gen Z on Byte',
#   'Gen Z on Byte',
#   'Gen Z on Byte',
#   'Gen Z on Byte',
#   'Gen Z on Byte',
#   'Gen Z on Byte',
#   'Best byte @ name debate below ️',
#   'Best byte @ name debate below ️',
#   'Best byte @ name debate below ️',
#   'Best byte @ name debate below ️',
#   'Best byte @ name debate below ️',
#   'Best byte @ name debate below ️',
#   'Best byte @ name debate below ️',
#   'Best byte @ name debate below ️',
#   'Best byte @ name debate below ️',
#   'I found a cool app',
#   'I found a cool app',
#   'I found a cool app',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'Why Every Byter Should Have A Podcast',
#   'I have the Keys | Stats Posted',
#   'I have the Keys | Stats Posted',
#   'I have the Keys | Stats Posted',
#   'I have the Keys | Stats Posted',
#   'I have the Keys | Stats Posted',
#   'I have the Keys | Stats Posted',
#   'I have the Keys | Stats Posted',
#   'I have the Keys | Stats Posted',
#   'I have the Keys | Stats Posted',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'Creating content while depressed',
#   'The reason I don’t go on byte that much',
#   'The reason I don’t go on byte that much',
#   'The reason I don’t go on byte that much',
#   'The reason I don’t go on byte that much',
#   'The reason I don’t go on byte that much',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'Official Sandwich for Byte',
#   'The sound feature isn’t working for me',
#   'The sound feature isn’t working for me',
#   'The sound feature isn’t working for me',
#   'The sound feature isn’t working for me',
#   'The sound feature isn’t working for me',
#   'The sound feature isn’t working for me',
#   'The sound feature isn’t working for me',
#   'The sound feature isn’t working for me',
#   'Byte beats vs sounds',
#   'Byte beats vs sounds',
#   'Byte beats vs sounds',
#   'Byte beats vs sounds',
#   'Byte beats vs sounds',
#   'Byte beats vs sounds',
#   'Byte beats vs sounds',
#   'Byte beats vs sounds',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Don’t ignore android when developing byte!',
#   'Happy Birthday to ConvincingHorse!',
#   'Happy Birthday to ConvincingHorse!',
#   'Happy Birthday to ConvincingHorse!',
#   'Happy Birthday to ConvincingHorse!',
#   'Happy Birthday to ConvincingHorse!',
#   'Happy Birthday to ConvincingHorse!',
#   'Happy Birthday to ConvincingHorse!',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Best Byte Loop Contest Top Ten! #LoopForGinger',
#   'Feeling silly… I still can’t use sounds?',
#   'Feeling silly… I still can’t use sounds?',
#   'Feeling silly… I still can’t use sounds?',
#   'Feeling silly… I still can’t use sounds?',
#   'Feeling silly… I still can’t use sounds?',
#   'Feeling silly… I still can’t use sounds?'],
#  'catagory': ['General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Hype for byte',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Ideas & Feature Requests',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Forum Forum',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'Bug Reports',
#   'Bug Reports',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'Bug Reports',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Off Topic',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'Community Happenings',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion',
#   'General Discussion'],
#  'name': ['domstaff ⭐️',
#   'HeyWhatsNewExpert',
#   'carkEmpathetic',
#   'Pgozur',
#   'Rafiki',
#   'freeze',
#   'AlmoExpert',
#   'Tatyana',
#   'ShonziThoAdmired',
#   'ShonziThoAdmired',
#   'FvidzExpert',
#   'ShallWeStory',
#   'ShonziThoAdmired',
#   'nina',
#   'expert.amateurAnniversary',
#   'azadeiExpert',
#   'domstaff ⭐️',
#   'domstaff ⭐️',
#   'domstaff ⭐️',
#   'domstaff ⭐️',
#   'domstaff ⭐️',
#   'NikMet',
#   'RodinBoi',
#   'DeCool',
#   'allintheoryEmpathetic',
#   'DeCool',
#   'MikeFaria',
#   'allintheoryEmpathetic',
#   'DeCool',
#   'AlwinTheSheriff',
#   'allintheoryEmpathetic',
#   'DeCool',
#   'colinkiamaLicensed',
#   'allintheoryEmpathetic',
#   'MikeFaria',
#   '_Orange',
#   'Imgay',
#   'neefy',
#   'NikMet',
#   'NikMet',
#   'NikMet',
#   'NikMet',
#   'Imgay',
#   'realarzcena',
#   'geo',
#   'geo',
#   'geo',
#   'BaileyOrdiway',
#   'BaileyOrdiway',
#   'imr.davis',
#   'Ciara',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'Imgay',
#   'rommie',
#   'Jaysander.b',
#   'JPHLicensed',
#   'PDSC',
#   'Beeshrine',
#   'BlackBruiserBrody',
#   'KinglyNerd',
#   'gabriell',
#   'imr.davis',
#   'Leocookman',
#   'iwantabyte',
#   'ShonziThoAdmired',
#   'ShonziThoAdmired',
#   'alleyreddExpert',
#   'DeCool',
#   'alleyreddExpert',
#   'DeCool',
#   'colinkiamaLicensed',
#   'rommie',
#   'Lxnria',
#   'misoramen',
#   'PDSC',
#   'mehamberLicensed',
#   'colinkiamaLicensed',
#   'bails',
#   'zozorae',
#   'TheTopicAtHand',
#   'Beegenics',
#   'DeCool',
#   'Libzy_itm',
#   'emmanuela',
#   'Lxnria',
#   'Geds',
#   'Ricekrispies69',
#   'realarzcena',
#   'JeridiculousLicensed',
#   'BaileyOrdiway',
#   'RodinBoi',
#   'MagicalVloggerAficionado',
#   'IansVoice87Anniversary',
#   'mauro',
#   'Rushbite',
#   'alleyreddExpert',
#   'meganjferguson',
#   'NikMet',
#   'friedeggroll',
#   'neefy',
#   'colinkiamaLicensed',
#   'neefy',
#   'HappinessQuickPlease',
#   'Geds',
#   'Geds',
#   'pugplug',
#   'J-Swizzle',
#   'sammmEmpathetic',
#   'sammmEmpathetic',
#   'arf',
#   'arf',
#   'ShawdGawd',
#   'HeyWhatsNewExpert',
#   'tybottofficial',
#   'HeyWhatsNewExpert',
#   'tybottofficial',
#   'tybottofficial',
#   'arf',
#   'theonerdicalEmpathetic',
#   'mason_paperEmpathetic',
#   'ShawdGawd',
#   'theonerdicalEmpathetic',
#   'pugplug',
#   'pugplug',
#   'pugplug',
#   'pugplug',
#   'mehamberLicensed',
#   'MikeFaria',
#   'neefy',
#   'neefy',
#   'allintheoryEmpathetic',
#   'plushbeats',
#   'PDSC',
#   'Rushbite',
#   'christyonceExpert',
#   'allintheoryEmpathetic',
#   'AbbyiguessLicensed',
#   'rommie',
#   'plushbeats',
#   'meganjferguson',
#   'mehamberLicensed',
#   'mehamberLicensed',
#   'mehamberLicensed',
#   'mehamberLicensed',
#   'mehamberLicensed',
#   'plushbeats',
#   'RobUKLicensed',
#   'ShonziThoAdmired',
#   'HappinessQuickPlease',
#   'RobUKLicensed',
#   'jayhaynay',
#   'NikMet',
#   'HappinessQuickPlease',
#   'plushbeats',
#   'VincenzoRozanov',
#   'VincenzoRozanov',
#   'NikMet',
#   'colinkiamaLicensed',
#   'colinkiamaLicensed',
#   'colinkiamaLicensed',
#   'colinkiamaLicensed',
#   'Beegenics',
#   'NikMet',
#   'NikMet',
#   'NikMet',
#   'NikMet',
#   'NikMet',
#   'NikMet',
#   'Aydin747',
#   'AIexanderReader',
#   'sem',
#   'Taemint67',
#   'ShonziThoAdmired',
#   'RodinBoi',
#   'B.C.MacNation',
#   'JussVibezAficionado',
#   'plushbeats',
#   'devynbExpert',
#   'alleyreddExpert',
#   'Aydin747',
#   'Aydin747',
#   'Aydin747',
#   'Aydin747',
#   'Aydin747',
#   'mauro',
#   'AlwinTheSheriff',
#   'Pac',
#   'RodinBoi',
#   'sem',
#   'nickbond',
#   'ashExpert💡',
#   'JussVibezAficionado',
#   'jellyjhar',
#   'gemikun',
#   'BeargummoExpert',
#   'plushbeats',
#   'nickbond',
#   'HotHashBrownLicensed',
#   'nickbond',
#   'mauro',
#   'mauro',
#   'mauro',
#   'oddbydefault',
#   'mehamberLicensed',
#   'LeaElizabeth',
#   'oddbydefault',
#   'oddbydefault',
#   'Kerbob97',
#   'Pac',
#   'dagdragon',
#   'LeaElizabeth',
#   'LeaElizabeth',
#   'Kerbob97',
#   'Kerbob97',
#   'Kerbob97',
#   'gabriell',
#   'gabriell',
#   'RonanLicensed',
#   'BaileyOrdiway',
#   'Ciara',
#   'emmanuela',
#   'gabriell',
#   'ShonziThoAdmired',
#   'RonanLicensed',
#   'iwantabyte',
#   'Imgay',
#   'MagicalVloggerAficionado',
#   'CubeOfCheese',
#   'MK142',
#   'Phinto',
#   'plushbeats',
#   'PDSC',
#   'iwantabyte',
#   'Lxnria',
#   'RobUKLicensed',
#   'Lxnria',
#   'plushbeats',
#   'Ricekrispies69',
#   'emmanuela',
#   'DeCool',
#   'theacstories',
#   'Ricekrispies69',
#   '3nJo1',
#   'Thededicatedartist',
#   'DeCool',
#   'plushbeats',
#   'plushbeats',
#   'plushbeats',
#   'Thededicatedartist',
#   'ryanmccarleyLicensed',
#   'Pac',
#   'gabriell',
#   'JaydenJones',
#   'colinkiamaLicensed',
#   'Thededicatedartist',
#   'Thededicatedartist',
#   'Thededicatedartist',
#   'gabriell',
#   'Beeshrine',
#   'gwynerso',
#   'JaursheLicensed',
#   'allintheoryEmpathetic',
#   'Rushbite',
#   'egirlcreampie',
#   'IansVoice87Anniversary',
#   'JeridiculousLicensed',
#   'emmanuela',
#   'JohnQReader',
#   'onkelchrispy',
#   'gabriell',
#   'gabriell',
#   'gabriell',
#   'gabriell',
#   'gabriell',
#   'gabriell',
#   'gabriell',
#   'gabriell',
#   'gabriell',
#   'Reallyahmed',
#   'kevin.f',
#   'dagdragon',
#   'Reallyahmed',
#   'Reallyahmed',
#   'plushbeats',
#   'MK142',
#   'imr.davis',
#   'MagicalVloggerAficionado',
#   'dagdragon',
#   'JaursheLicensed',
#   'Thededicatedartist',
#   'neefy',
#   'dagdragon',
#   'Phinto',
#   'JohnQReader',
#   'plushbeats',
#   'plushbeats',
#   'plushbeats',
#   'plushbeats',
#   'plushbeats',
#   'plushbeats',
#   'plushbeats',
#   'Shanks',
#   'neefy',
#   'neefy',
#   'Kerbob97',
#   'Shanks',
#   'Shanks',
#   'Shanks',
#   'Shanks',
#   'CubeOfCheese',
#   'ShonziThoAdmired',
#   'colinkiamaLicensed',
#   'JeridiculousLicensed',
#   'Kerbob97',
#   'plushbeats',
#   'CubeOfCheese',
#   'CubeOfCheese',
#   'cnzfnz',
#   'RodinBoi',
#   'evyncollins',
#   'domstaff ⭐️',
#   'MK142',
#   'Thededicatedartist',
#   'Kerbob97',
#   'cnzfnz',
#   'cnzfnz',
#   'cnzfnz',
#   'cnzfnz',
#   'cnzfnz',
#   'mynameiskawena',
#   'snapbackdad',
#   'ConvincingHorse',
#   'DeCool',
#   'neefy',
#   'ConvincingHorse',
#   'mynameiskawena',
#   'The_Ginger',
#   'Paranoid_GUY',
#   'ZacMcMillan',
#   'calza_soze',
#   'EdwinnboiAnniversary',
#   'allintheoryEmpathetic',
#   'imr.davis',
#   'SymphonicRon',
#   'WolfHarrington',
#   'bradleywithane',
#   'CubeOfCheese',
#   'GeneMachine',
#   'KenAnDReas',
#   'Beegenics',
#   'JaursheLicensed',
#   'allintheoryEmpathetic',
#   'Paranoid_GUY',
#   'hnt',
#   'snapbackdad',
#   'The_Ginger',
#   'The_Ginger',
#   'p0rk',
#   'moj',
#   'ryanmccarleyLicensed',
#   'ryanmccarleyLicensed',
#   'p0rk',
#   'p0rk'],
#  'likes': ['114',
#   '8',
#   '9',
#   '6',
#   '18',
#   '5',
#   '3',
#   '3',
#   '6',
#   '6',
#   '3',
#   '3',
#   '3',
#   '3',
#   '3',
#   '2',
#   '114',
#   '5',
#   '12',
#   '8',
#   '17',
#   '20',
#   '3',
#   '9',
#   '11',
#   '4',
#   '6',
#   '',
#   '',
#   '3',
#   '',
#   '2',
#   '1',
#   '4',
#   '3',
#   '1',
#   '1',
#   '5',
#   '20',
#   '2',
#   '1',
#   '2',
#   '13',
#   '3',
#   '1',
#   '1',
#   '2',
#   '3',
#   '3',
#   '3',
#   '1',
#   '13',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '3',
#   '',
#   '',
#   '1',
#   '1',
#   '1',
#   '18',
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '6',
#   '2',
#   '',
#   '1',
#   '2',
#   '1',
#   '1',
#   '1',
#   '',
#   '',
#   '18',
#   '5',
#   '5',
#   '4',
#   '4',
#   '2',
#   '5',
#   '2',
#   '2',
#   '5',
#   '1',
#   '1',
#   '1',
#   '5',
#   '9',
#   '3',
#   '1',
#   '2',
#   '2',
#   '2',
#   '2',
#   '2',
#   '1',
#   '1',
#   '',
#   '2',
#   '1',
#   '',
#   '',
#   '',
#   '1',
#   '',
#   '9',
#   '3',
#   '3',
#   '3',
#   '1',
#   '3',
#   '2',
#   '3',
#   '1',
#   '',
#   '',
#   '',
#   '1',
#   '1',
#   '1',
#   '',
#   '1',
#   '1',
#   '1',
#   '3',
#   '2',
#   '3',
#   '1',
#   '34',
#   '2',
#   '2',
#   '3',
#   '1',
#   '2',
#   '2',
#   '2',
#   '3',
#   '2',
#   '2',
#   '2',
#   '2',
#   '',
#   '34',
#   '2',
#   '1',
#   '3',
#   '2',
#   '',
#   '1',
#   '2',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '3',
#   '3',
#   '1',
#   '',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '',
#   '',
#   '',
#   '',
#   '1',
#   '23',
#   '4',
#   '4',
#   '4',
#   '4',
#   '3',
#   '3',
#   '2',
#   '2',
#   '2',
#   '1',
#   '23',
#   '3',
#   '3',
#   '2',
#   '3',
#   '56',
#   '5',
#   '5',
#   '2',
#   '1',
#   '3',
#   '7',
#   '1',
#   '1',
#   '2',
#   '1',
#   '1',
#   '',
#   '1',
#   '2',
#   '56',
#   '17',
#   '16',
#   '',
#   '2',
#   '1',
#   '',
#   '',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   '8',
#   '',
#   '1',
#   '3',
#   '2',
#   '',
#   '8',
#   '4',
#   '2',
#   '2',
#   '3',
#   '',
#   '',
#   '',
#   '',
#   '4',
#   '',
#   '',
#   '',
#   '5',
#   '4',
#   '1',
#   '2',
#   '1',
#   '2',
#   '',
#   '1',
#   '',
#   '5',
#   '1',
#   '',
#   '7',
#   '3',
#   '3',
#   '1',
#   '1',
#   '1',
#   '7',
#   '7',
#   '2',
#   '16',
#   '3',
#   '4',
#   '7',
#   '5',
#   '2',
#   '2',
#   '2',
#   '1',
#   '1',
#   '2',
#   '1',
#   '16',
#   '1',
#   '2',
#   '2',
#   '3',
#   '3',
#   '1',
#   '',
#   '',
#   '6',
#   '1',
#   '',
#   '6',
#   '1',
#   '',
#   '1',
#   '7',
#   '',
#   '6',
#   '2',
#   '2',
#   '2',
#   '2',
#   '1',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '1',
#   '',
#   '2',
#   '1',
#   '1',
#   '',
#   '2',
#   '2',
#   '1',
#   '1',
#   '6',
#   '',
#   '1',
#   '2',
#   '1',
#   '',
#   '6',
#   '',
#   '6',
#   '2',
#   '1',
#   '19',
#   '',
#   '',
#   '',
#   '6',
#   '2',
#   '',
#   '',
#   '7',
#   '13',
#   '3',
#   '8',
#   '3',
#   '3',
#   '5',
#   '13',
#   '28',
#   '9',
#   '7',
#   '6',
#   '8',
#   '6',
#   '7',
#   '6',
#   '4',
#   '5',
#   '5',
#   '5',
#   '1',
#   '5',
#   '5',
#   '4',
#   '1',
#   '1',
#   '2',
#   '28',
#   '7',
#   '1',
#   '',
#   '1',
#   '',
#   '1',
#   '1'],
#  'content': ['For important (and mostly unavoidable) reasons that we’ll go over another time, Byte alters video files when loading them in order to prepare them for seamless looping. Vine did this as well.\nBecause of this, you will generally experience that some of your audio is “cut off” or garbled when you import it. If you have audio that is already designed to loop perfectly, you can make the following changes to get a near perfect loop:\nTechnique 1 for 30 FPS videos\nAdd 3 frames (aka 0.1s) to both the beginning and end of the video.\nTechnique 2 for 60 FPS videos\nAdd 6 frames (aka 0.1s) to both the beginning and end of the video.\nTechnique 3 (for complex audio, non-30/60 FPS video, or if the above doesn’t work)\n\nStart with your intended audio loop, and make sure it’s no longer than 7.8s\nCopy 150ms of audio from the beginning of the loop and append it to the end\n\nAssuming you started with a 7.8s file, it should now be 7.95s\nAdd 50ms of silence to the beginning of the file\nThe file should now be 8s\n\nUse this audio as the basis for your video (and make sure the video track is the same length as the final audio file), and you should get a near perfect audio loop.\nWe’ll work on making this easier and less necessary in the future.',
#   'Very helpful tips, thanks. ',
#   'thank you dom, very cool!',
#   'Thanks for this!',
#   'thanks for the tip \n\n48B616CA-0E92-44A9-9937-BEFD79921B3D.jpeg750×146 13.8 KB\n',
#   'I’m curious if following this procedure will allow for looping on iOS even if it is uploaded on an Android device ?',
#   'Thanks for this Dom ',
#   'editing tips \nphannies of 2018 will understand lmao',
#   'videos seem to loop differently on android and ios.\nif i post a perfect loop on android, it cuts too short when playing it back on ios.\nthe same vice versa, a perfect loop posted from ios doesn’t loop on android, but does on ios\nwill this be fixed to make them loop exactly the same on both OS?',
#   'sounds good👍🏻 thank you!\ni remember on my really old crappy android (i think it was a samsung galaxy s3 mini) back in the days of vine, it wouldn’t loop at all, just cut completely at the end. but i rarely used my phone for vine anyway',
#   'OMG this is why you are the best !!!  We all Love You Dom ',
#   'You the legend.',
#   'it’s great! i just went back and watched a recent loop of mine and it’s almost perfection  excited to test it some more.\ncongrats on cracking it guys! ',
#   'Game changer, we love you guys and all your hard work  thank you!!',
#   'This is incredible! thank you Dom \nMoving past the old, and coming in with the new ',
#   'Any tips for loops lasting longer than 6.3 seconds? I have one or two that I have been working on, and it looks like video is cut out too (unless I’m bad at looping, but who knows )',
#   'For important (and mostly unavoidable) reasons that we’ll go over another time, Byte alters video files when loading them in order to prepare them for seamless looping. Vine did this as well.\nBecause of this, you will generally experience that some of your audio is “cut off” or garbled when you import it. If you have audio that is already designed to loop perfectly, you can make the following changes to get a near perfect loop:\nTechnique 1 for 30 FPS videos\nAdd 3 frames (aka 0.1s) to both the beginning and end of the video.\nTechnique 2 for 60 FPS videos\nAdd 6 frames (aka 0.1s) to both the beginning and end of the video.\nTechnique 3 (for complex audio, non-30/60 FPS video, or if the above doesn’t work)\n\nStart with your intended audio loop, and make sure it’s no longer than 7.8s\nCopy 150ms of audio from the beginning of the loop and append it to the end\n\nAssuming you started with a 7.8s file, it should now be 7.95s\nAdd 50ms of silence to the beginning of the file\nThe file should now be 8s\n\nUse this audio as the basis for your video (and make sure the video track is the same length as the final audio file), and you should get a near perfect audio loop.\nWe’ll work on making this easier and less necessary in the future.',
#   'it should',
#   'we’re currently working on trying to get them as close as possible. they were not the same on vine but we’re trying to do a better job on byte',
#   'this is in the top of the thread but just to repost it:\n\n\n\n dom:\n\nNote: this tip currently applies to looping on iOS only. By necessity, Android currently has a different looping algorithm and probably will for some time.\n\n',
#   'the android update today should have looping behavior that is very similar to the iOS looping behavior. very excited about this because we never quite cracked this at vine ',
#   'If I buy a mansion in the Hollywood Hills, would anyone want to move in? We could call it the Byte House and collab on the reg. Let me know!',
#   '',
#   'What would we be biting onto?',
#   'ummmmmmm… can we start an artist commune instead?  hype house is definitely not something I want to take away from tiktok',
#   'But I wanna bite stuff, man',
#   'How much is rent, and can my dogs come with me ',
#   'I have grapes? ',
#   'Which colour',
#   'Could’ve swore someone was trying to do this awhile back lol',
#   '@orange',
#   'nah, i dont eat the homies',
#   'Omg wahhhh lmao',
#   'My mom humor fails. Or my high humor. Or both.',
#   'Damn, im out here paying $1,100/month for a 2 story 4 bedroom ',
#   'Count me in',
#   'No ',
#   'any room for a Brit ',
#   'If I buy a mansion in the Hollywood Hills, would anyone want to move in? We could call it the Byte House and collab on the reg. Let me know!',
#   'Doesn’t have to be an either-or type of thing. Just a bunch of creators living in the same general area would be awesome for the app & community.',
#   'I was just looking- there’s a bunch you can get for around $1,200-1,400/month per room. Pretty cheap for LA. And of course dogs are always welcome!',
#   'Also, I don’t know what a hype house is, I don’t do TikTok. This would be a house of creative Byters who want to produce awesome content and collaborate on ideas/videos.',
#   'image1200×675 254 KB\nHey guys I‘m back from my ban  I heard that a lot of people missed me (like @addisonre @egirlcreampie @geo @ciara)  it’s okay don’t cry  I worked on my byte fame for a day and I‘m famous now  thanks to @FaizalDawx he banned me  he’s my stalker he stalked my ip address which is weird but I‘m his favorite that’s why he did that  also thanks to my b̶̧̨͎̪̫̜̻͍̱̿͗̽̾̅̒̕e̸̝̰͔̽́̂̉̕ș̷̛̠͈̼̉̿̋̔̔̀̈́͠ͅt̸̺̗̔̎͐̎̋͘y̸̹̿̈͑̑ @Maddy_lions she really helped me through this hard time  she’s ignoring me a lot but I‘ll forgive her \nALSO I decided that this is a thread where  everyone (Millennials please don’t spam that much y‘all aren’t funny at all go watch Harry Potter while eating a avocado toast bye )can spam and gen z humor is allowed!! The only rules are no bullying(I know it’s hard (furries ) but I‘ll allow it
�̞̦̭̺͖̘̱͖̰̠̬̫̫̼̱̮̺̣͉̤̦̻͍͖̼̠͎̫̘̤͈̮̻͇̠̼̠̞̖̱̥͓̣̰̮̦͇̲̭̗̲̯̰̭̖̱̱̣͖̪̦̭̞̼͍͇͚̭̘̰̰͉̹͚̒̏͌̋͊̾̂͋̔̈̍̋̆̊̄̏͆̉̌̋̇̔̌͗̀͌̂̿͆̉̏͛̽̆̌̈́͋̐̈̉̅̍̍̇́̏̃̓̾̿̒̿̾̋̾̓̕͘̕͘̕̕̚̚̚͘̚͜͜͜͜͜͜͠͠͝ͅͅͅͅͅͅ    tiktok   \n\n\nedit5:\nWTF HAHHAHAHAHA\n\n\n\n egirlcreampie:\n\nomg i’m sorry kitten your discord admin d ...
#   '',
#   'i missed u loads bb ',
#   'he had ur ip address???!?!??! saifty 100%',
#   'idk if ay of my family members have accts on here i highly doubt it bcs i havent told any of them abt this but my mums a stalker so hi mum ik ur reading this',
#   'I’m a millenial and I’m also a rebel so here I am. Hello.',
#   'You can’t tell me what to do. You’re not my real mom.',
#   'What are the actual drugs you on? Wow.',
#   'Coke',
#   'image1200×675 254 KB\nHey guys I‘m back from my ban  I heard that a lot of people missed me (like @addisonre @egirlcreampie @geo @ciara)  it’s okay don’t cry  I worked on my byte fame for a day and I‘m famous now  thanks to @FaizalDawx he banned me  he’s my stalker he stalked my ip address which is weird but I‘m his favorite that’s why he did that  also thanks to my b̶̧̨͎̪̫̜̻͍̱̿͗̽̾̅̒̕e̸̝̰͔̽́̂̉̕ș̷̛̠͈̼̉̿̋̔̔̀̈́͠ͅt̸̺̗̔̎͐̎̋͘y̸̹̿̈͑̑ @Maddy_lions she really helped me through this hard time  she’s ignoring me a lot but I‘ll forgive her \nALSO I decided that this is a thread where  everyone (Millennials please don’t spam that much y‘all aren’t funny at all go watch Harry Potter while eating a avocado toast bye )can spam and gen z humor is allowed!! The only rules are no bullying(I know it’s hard (furries ) but I‘ll allow it only if you bully your friends)and no politics please because else I‘ll get banned again… I need more fame soo here’s a link to a byte I made https://byte.co/b/E04TZPK1JvL 27 thanks for reading😻 I appreciate all of you❤️\nedit:\nTHANK YOU(I made those comments) \n\n\n\n Timmy_Holfigger:\n\nOkay, I’m not a millennial or Gen Z but I came here to say that I am thoroughly impressed at the Salad Fingers comment up there  You Gen Z’ers get my vote! \n\n\nedit 2:\nWE ALL KNEW IT BUT THANK YOU MADDY MOMMY \n\n\n\nNew channels!\n\n\n@Imgay is my favorite \n\n\nedit3:\nTHE KING HIMSELF SPOKE \n\n\n\n TomWho:\n\nThis is the prettiest thread in the forum. \n\n\nedit4:\nNIKO THATS THE SPIRIT \n\n\n\n Niko:\n\ncan  we  pleaseeee    get  rid  of    s̷̢̡̡̨̡̢̨̢̡̨̢̨̛̛̛̛̛̛̥̱̬͎̫̦͈̯͎͎͚͚͙͖̲͕̙̤̰̲̮̫͕̭̞̺͍̲̺̰̝̘̞̤͉̦̹̞̜̯̤͈̦͔̫̠͙̬̲̱̙̘̗͉̖͉̜̮͍�
��﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽﷽',
#   'Don’t stay too long ',
#   'Wow',
#   'hëłłō  í  łīkë  rùštŷ  špòōñš  hè  î  łîkē  tö  töúćh  thëm  ñīę  thé  féėłíñg  öf  rùśt  ágãįńśt  mŷ  śâłäd  fīñgêrś  įś  âłmóśt  ōrgáśmïć  ',
#   'ꫝꫀꪶꪶꪮ  𝓲   like  ŔÛśțý  Şpűńş  i   like  to   t҈o҈u҈  c҈.       h҈:metal:  t҈  h҈e҈   m҈ the     feeling  of  ꋪꀎꌚ꓄  against  my  ነልረልጋ  f҉i҉n҉g҉e҉r҉s҉',
#   'What ',
#   'Hi imy guys\nAny OG that I most likely dont know of yet - drop your @ I wanna follow new ppl that have been on the app for awhile!!\nPs hi newbies i see you too',
#   '@Jaysander.b',
#   '@JPH\nIt’s a complete sentence',
#   'jaamiealoone',
#   'You have me added? If not you definitely want my cringeposts',
#   '@kurosarakokuou',
#   "\n\n\nbyte.co 1\n\n\n\n@KinglyNerd's bytes 1\nA wingnut, a goofball and a knucklehead mcspazatron trying to make an audience snort.\n\n\n\n\n\n",
#   '@gabriell ',
#   'Y’all know me, still the same OG, but I been low key.',
#   '@Leocookman',
#   'newbies matter @iwantabyte',
#   "\n\n\nbyte.co 2\n\n\n\n@ShonziTho's bytes 2\nya'll give me gas\nlondon / 22 / old viner\npersonal: @shonzi (if ya wanna see my face😳)\n\nbyte ig: shonzi.byte\ntwitter: ShonziTho\n\n\n\n\n\n",
#   'this is for ogs only…',
#   'https://byte.co/@alley 6',
#   'Oh. ON GOD?',
#   'on god bro:)',
#   'I’m crying ',
#   'So does this mean that… You’re back?',
#   'Hi imy guys\nAny OG that I most likely dont know of yet - drop your @ I wanna follow new ppl that have been on the app for awhile!!\nPs hi newbies i see you too ',
#   'Opinion on tiktokers hopping on byte',
#   'The equivalent to byters and bikers on Tiktok people use whatever app fits their fancy.',
#   'It’s nice having new people hopping on byte especially tiktokers, however I don’t want them having all the clout just because they’re more relevant i.e huge followings on other platforms, extremely good looking, blowing up for the most stupidest reasons like staring at the screen, f4f/L4L scams, mindlessly speaking out on controversially sensitive topics etc.',
#   'I feel like there is LOT more younger kids on byte now. Some of them are adorable little cherubs who just want someone to hype them up and show them love and the others are actually brats who think it’s cool to freely spread hate at anyone and everything for no reason at all',
#   'I know a few people that were on here early that didn’t have an audience because there weren’t enough people around their age but now…',
#   'I think its a good thing having them try out byte, with the hope that they stay. There is enough room for everyone on the app, and they might be able to bring more insight into new features/ how the app could work better etc',
#   'First, I wanna say I love the open mindedness of the previous replies, the negative things I see in people’s comments about tiktokers invading and whatnot isn’t representative of what the byte community is about. For the most part, we’re about acceptance and support towards good content that both creators and viewers enjoy, which I love.\nSo, I feel that tiktokers should be welcome too, and hopefully they’ll grow to love byte the way it is and just as much as we do, and maybe be inspired to make and support different kinds of content.',
#   'I don’t mind people from Tiktok on Byte, but they need to realize that Byte is way different than Tiktok.\nTo me, the way Tiktok runs on trends is like a popularity contest.  You can get a good amount of views easily for doing a trend, but the best looking/most popular people doing the same trend you did will get the most views and followers overall.\nByte, on the other hand, is more of a work for your views thing.  Most of the time, you have to put out good content that people are going to like and view a lot for you to get views and followers.  You definitely get less views on Byte than you would on Tiktok.\nKnowing this, I just don’t want Byte to turn into a mini Tiktok, but I always will welcome people from Tiktok if they understand the difference.',
# ...
#   'me too ',
#   'Sounds may not loop but beats 100% will.',
#   'We still need plenty of Beats. Many of them are kinda wack so we need variety. They serve a purpose (perfect loops) so why phase them out?',
#   'I would love the option to double loop the byte beats for Longer bytes since it goes to a slow mo version currently.\nI say an option, because sometimes the slow mo actually works better ',
#   'i don’t think so. It’ll be more like tik tok and triller. Honestly hyped for it',
#   'With the addition of sounds I wonder if byte beats are going to be phased out. I really wanted to become a byte beats creator so that would be a shame',
#   'Big true!',
#   'After using byte for the past week, I have noticed some differences between how the app runs on IOS vs on android. We are missing a lot of different features, to name a few: customizable app icons, stickers, etc. (if you guys have any others you can leave them in the replies) I totally understand that developing is way harder on android because it runs on so many different types of phones, but the android market is important to pay attention to nonetheless.\n\nNone of these have been deal breaking, but the accumulation of different bugs and missing features, all while seeing iPhone get more things can be frustrating and drive android users away from the app.\n\nI don’t know the specific number for this app of the ratio of android to iPhone users, but in America, although 58% of people owned iPhones, 42% of people android phones in 2019. (source) This number is slowly rising, too. Looking past the US, the majority of European countries have over 50% Android users.\n\nSo please, keep consistency between your platforms; it should feel like the same app whether you’re on IOS or android. The android market is a huge and expanding one, so please don’t ignore us when developing your app!\n\nP.S. did I put this in the right category? lol\n-Connor',
#   'one thing i know is that the app icon thing is harder to do on android than it is on iOS, not many apps have that on android',
#   'They’re not ignoring Android. Byte has a small team of developers.',
#   'thanks for writing this. we love droids \nright now there’s 1 android developer who is an absolute champion on the team, and 2 ios devs. ios is also a little easier to develop for because of apple’s approach to development frameworks. we’re trying to hire someone and get this more equal but just so you know it has nothing to do with our preferences and everything to do with it both taking more time and (currently) having fewer people on android',
#   'It’s even crazier in countries like Germany where Android has a 80% marketshare but I guess it’d be hard to overcome TikTok here anytime soon just because most people probably never heard of the TikTok controversy here, Imo they should focus very hard on India since a lot of India’s are going anti china over there and Byte is a solid replacement for TikTok',
#   'I’m a graphic designer. I cant code but i do use adobe XD.',
#   'Android is my go to example of a fractal environment in software development.\nIt’s gotten better, but here’s the branch breakdown.\nGoogle makes OS.  They are in beta for 11 right now.  Each new version has multiple iterations, and there are still a ton of people using much older versions.\nLet’s just say you are concerned with developing for OS 8 to Beta OS 11.\nThen, the phone Manufacturers step in, and make custom versions of the OS for each phone model to optimize it’s performance.\nThen, the carriers step in and add their special sauce (bloatware) that typically breaks something in either Google’s OS, or the manufacturer’s version.\nIn a lot of the older versions, you could only get the updates from the carrier.  Which can and has broken or even bricked many a phone.',
#   'After using byte for the past week, I have noticed some differences between how the app runs on IOS vs on android. We are missing a lot of different features, to name a few: customizable app icons, stickers, etc. (if you guys have any others you can leave them in the replies) I totally understand that developing is way harder on android because it runs on so many different types of phones, but the android market is important to pay attention to nonetheless.\n\nNone of these have been deal breaking, but the accumulation of different bugs and missing features, all while seeing iPhone get more things can be frustrating and drive android users away from the app.\n\nI don’t know the specific number for this app of the ratio of android to iPhone users, but in America, although 58% of people owned iPhones, 42% of people android phones in 2019. (source) This number is slowly rising, too. Looking past the US, the majority of European countries have over 50% Android users.\n\nSo please, keep consistency between your platforms; it should feel like the same app whether you’re on IOS or android. The android market is a huge and expanding one, so please don’t ignore us when developing your app!\n\nP.S. did I put this in the right category? lol\n-Connor',
#   'true ',
#   'also would it be ok to tag dom in this? idk if i should LOL',
#   'LMAO yeah he already did   ',
#   'RIP, totally understand. that makes a lot more sense. tell the android developer we love them and appreciate their hard work  ',
#   'It’s 9:31pm here in Hawaii so I still have time to make this forum!\nBut then again, you live in Australia…and are many hours ahead of me…so does that mean your birthday is tomorrow my time???\nTime zones confuse me so much…\nWell anyways, HAPPY BIRTHDAY @ConvincingHorse! And I will also always simp for you',
#   'Happy birthday to the most convincing of horses!! It’s currently 1:13am July 25th where I am ',
#   ' living in Australia and having overseas friends is good because you get two days worth of one birthday!!! ',
#   'queeeeeEEEEEEEEN!',
#   'happy birthday to our Queen Horse  (yes I will keep wishing you a happy birthday each time)',
#   'Thank you @mynameiskawena @snapbackdad @DeCool @neefy and so many others on the app!\nY’all rly helped make my birthday yesterday really sweet and special on a weird birthday in solo isolation so it’s very appreciated and the love is very much felt and seen ',
#   'It’s 9:31pm here in Hawaii so I still have time to make this forum!\nBut then again, you live in Australia…and are many hours ahead of me…so does that mean your birthday is tomorrow my time???\nTime zones confuse me so much…\nWell anyways, HAPPY BIRTHDAY @ConvincingHorse! And I will also always simp for you ',
#   'Hello Bytonians!!!\nBefore the list I want to thank @paranoid_guy and  @kasonbohn again for their donations to the contest. I also want to congratulate @genemachine for winning my heart over for the donation. I will be donating $100 to the Riley Hospital for Children.\nI gotta be honest… in the beginning of this I wasn’t sure how many people were gonna compete, submit, or be interested. But the support and submissions have absolutely blown me away. All of the interest and submissions has also made it near impossible to select only ten top loops, but I made some tough decisions and now have the list before you. You should all be proud of the loops you made, whether you see them up on the top ten or not. Seriously, thank you guys so much for making this contest such a blast.\nThe poll will be up until Thursday July 30th, and the top three winners will be announced via Byte and on here. In the case of a tie for the top three positions, I will have the tied members both submit to be either rock, paper, or scissors to “fairly” decide the winner.\nHere are your top ten:\nWolfharrington 62\nbradleywithane 48\nBeegenics 48\nSymphonicron 48\njordan_presley 49\ndasha 46\ncubeofcheese 43\nedwinnboi 45\nkwrrk 47\nstardustnow 48\nPlease click on the names above to watch the top ten post and vote below for who you think deserves the number one spot!\n Wolfharrington bradleywithane Beegenics Symphonicron jordan_presley dasha cubeofcheese edwinnboi kwrrk stardustnow59votersResults will be shown once closed.\nAlso, here are a few honorable mentions that were very close to making the top ten:\nthecatholicchurch 24\nkarielea2 21\nGuert 22\nAgain, thank you all for making this contest so great!',
#   'how the heck do you pick from those. like damn!!!',
#   'YESSSS!!! These are amazing!!',
#   'Nice work everyone! Wish I could vote more than once',
#   'Thank you for hosting this contest. I see a lot of great and awesome loops!! I saw a few others that did not make it and they were truly amazing!! Congrats to all that made it to top 10!! I am very proud to be included in these top 10. Thank you for all that had submitted so many great loops!',
#   'Congratulations to everyone nominated \nI’ve literally changed my vote three times.This is hard! ',
#   'I know who I’m voting for',
#   'Wow! It’s an honor to be listed amongst all of these talented people. I wouldn’t have wanted the job of choosing a top 10 here because there were so many cool submissions. Thank you Ginger for igniting a spark within the community. I had so much fun watching everyone’s loops.',
#   'Wow! ',
#   'three of my favorite things: video loops, being nominated for something, and democracy. good luck folks',
#   'Thank you for this! I’m honored ',
#   'Thank you so much G. It means the world to me and Ik those kids are gonna love and appreciate the help of that money, it melts my heart to see those in need get help that you\u200b:pray:t4:',
#   'It’s normal if I don’t know them ??',
#   'Damn what an honor  I’m so ducking flattered to be nominated and actually see people vote for me what a trip.\nThank you guys so much',
#   'These are all so, so, SO GOOD!!',
#   'creativity matters more than likes ',
#   'im just gonna close my eyes and click at this point ',
#   'Cast my vote! Good luck everyone ',
#   'So hard to choose ',
#   'Hello Bytonians!!!\nBefore the list I want to thank @paranoid_guy and  @kasonbohn again for their donations to the contest. I also want to congratulate @genemachine for winning my heart over for the donation. I will be donating $100 to the Riley Hospital for Children.\nI gotta be honest… in the beginning of this I wasn’t sure how many people were gonna compete, submit, or be interested. But the support and submissions have absolutely blown me away. All of the interest and submissions has also made it near impossible to select only ten top loops, but I made some tough decisions and now have the list before you. You should all be proud of the loops you made, whether you see them up on the top ten or not. Seriously, thank you guys so much for making this contest such a blast.\nThe poll will be up until Thursday July 30th, and the top three winners will be announced via Byte and on here. In the case of a tie for the top three positions, I will have the tied members both submit to be either rock, paper, or scissors to “fairly” decide the winner.\nHere are your top ten:\nWolfharrington 62\nbradleywithane 48\nBeegenics 48\nSymphonicron 48\njordan_presley 49\ndasha 46\ncubeofcheese 43\nedwinnboi 45\nkwrrk 47\nstardustnow 48\nPlease click on the names above to watch the top ten post and vote below for who you think deserves the number one spot!\n Wolfharrington bradleywithane Beegenics Symphonicron jordan_presley dasha cubeofcheese edwinnboi kwrrk stardustnow59votersResults will be shown once closed.\nAlso, here are a few honorable mentions that were very close to making the top ten:\nthecatholicchurch 24\nkarielea2 21\nGuert 22\nAgain, thank you all for making this contest so great!',
#   'Oy vey you’re telling me. Was just telling @calza_soze how I had to reel myself in from making it a top paid twenty haha. But this gives me inspiration to do it again in the future!',
#   'I heard that it’s out on android, but I still can’t find where to use it. I’ve updated, uninstalled and reinstalled… please don’t roast me too much if I am completely mistaken about this u.u',
#   'me neither!! would love to find out.',
#   'are you using the android beta?',
#   'i honestly fell asleep, but quoted are android/ios beta opt-in (if you needed them, and didnt already grab them)\n\n\n\n16 second bytes, day 2\n\n\n\nios: https://testflight.apple.com/join/LYr3GdT1 \n\nandroid: https://t.co/BlU5gRiRhv?amp=1 \n\n\n\n',
#   'I heard that it’s out on android, but I still can’t find where to use it. I’ve updated, uninstalled and reinstalled… please don’t roast me too much if I am completely mistaken about this u.u',
#   'Oh, is it on beta only still for android? that would explain it lol'],
#  'date': ["Oct '19",
#   "Oct '19",
#   "Oct '19",
#   "Oct '19",
#   "Oct '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Oct '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   "Dec '19",
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '13d',
#   '3d',
#   '3d',
#   '3d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '5h',
#   '3h',
#   '2h',
#   '2h',
#   '2h',
#   '3d',
#   '8h',
#   '8h',
#   '8h',
#   '7h',
#   '7h',
#   '4h',
#   '3h',
#   '3h',
#   '3h',
#   '3h',
#   '2h',
#   '1h',
#   '8h',
#   '5d',
#   '5d',
#   '5d',
#   '5d',
#   '5d',
#   '5d',
#   '5d',
#   '5d',
#   '5d',
#   '5d',
#   '5h',
#   '3h',
#   '2h',
#   '1h',
#   '1h',
#   '43m',
#   '23m',
#   '20m',
#   '5d',
#   '5d',
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   "Jan '19",
#   '3d',
#   '3d',
#   '3d',
#   '3d',
#   '3d',
#   '3d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '3h',
#   '3d',
#   '3d',
#   '3d',
#   '2d',
#   '2d',
#   '16h',
#   '8h',
#   '7h',
#   '6h',
#   '6h',
#   '4h',
#   '3h',
#   '18m',
#   '16h',
#   '3h',
#   '3h',
#   '6h',
#   '6h',
#   '6h',
#   '5h',
#   '5h',
#   '5h',
#   '6h',
#   '6h',
#   '6h',
#   '5h',
#   '5h',
#   '5h',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'Apr 30',
#   'May 1',
#   '5h',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'Apr 29',
#   'May 8',
#   'May 8',
#   'May 8',
#   'May 8',
#   'May 8',
#   'May 8',
#   'May 8',
#   'May 8',
#   'May 9',
#   'May 9',
#   'May 9',
#   'May 9',
#   'May 9',
#   'May 9',
#   'May 10',
#   'May 8',
#   'May 9',
#   'May 10',
#   '16h',
#   '7h',
#   '7h',
#   '16h',
#   '6h',
#   '15h',
#   '14h',
#   '13h',
#   '7h',
#   '7h',
#   '15h',
#   '12h',
#   '11h',
#   '7h',
#   '7h',
#   '16h',
#   '16h',
#   '16h',
#   '15h',
#   '11h',
#   '7h',
#   '16h',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '16h',
#   '16h',
#   '8h',
#   '1d',
#   '8h',
#   '8h',
#   '8h',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '16h',
#   '15h',
#   '13h',
#   '9h',
#   '2d',
#   '16h',
#   '16h',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '10h',
#   '1d',
#   '1d',
#   '23h',
#   '5d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '3d',
#   '3d',
#   '15h',
#   '5d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '4d',
#   '11h',
#   '15h',
#   '14h',
#   '12h',
#   '15h',
#   '13h',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '19h',
#   '17h',
#   '13h',
#   '2d',
#   '16h',
#   '16h',
#   '16h',
#   '16h',
#   '16h',
#   '16h',
#   '2d',
#   '1d',
#   '1d',
#   '15h',
#   '2d',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '22h',
#   '20h',
#   '16h',
#   '16h',
#   '1d',
#   '21h',
#   '16d',
#   '16d',
#   '16d',
#   '16d',
#   '2d',
#   '1d',
#   '16h',
#   '16d',
#   '16d',
#   '16d',
#   '16d',
#   '16d',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '1d',
#   '16h',
#   '1d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '2d',
#   '21h',
#   '20h',
#   '20h',
#   '16h',
#   '21h',
#   '20h']}

# %%
df = pd.DataFrame.from_dict(posts_dict,orient='index')
df
# Out:
#                                                         0    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                            domstaff ⭐️
# likes                                                   114
# content   For important (and mostly unavoidable) reasons...
# date                                                Oct '19
#
#                                                         1    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                      HeyWhatsNewExpert
# likes                                                     8
# content                         Very helpful tips, thanks.
# date                                                Oct '19
#
#                                                         2    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                         carkEmpathetic
# likes                                                     9
# content                           thank you dom, very cool!
# date                                                Oct '19
#
#                                                         3    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                                 Pgozur
# likes                                                     6
# content                                    Thanks for this!
# date                                                Oct '19
#
#                                                         4    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                                 Rafiki
# likes                                                    18
# content   thanks for the tip \n\n48B616CA-0E92-44A9-9937...
# date                                                Oct '19
#
#                                                         5    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                                 freeze
# likes                                                     5
# content   I’m curious if following this procedure will a...
# date                                                Dec '19
#
#                                                         6    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                             AlmoExpert
# likes                                                     3
# content                                Thanks for this Dom
# date                                                Dec '19
#
#                                                         7    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                                Tatyana
# likes                                                     3
# content   editing tips \nphannies of 2018 will understan...
# date                                                Dec '19
#
#                                                         8    \
# title     Tip: External editing for near-perfect audio l...
# catagory                                 General Discussion
# name                                       ShonziThoAdmired
# likes                                                     6
# content   videos seem to loop differently on android and...
# date                                                Dec '19
#
#                                                         9    ...  \
# title     Tip: External editing for near-perfect audio l...  ...
# catagory                                 General Discussion  ...
# name                                       ShonziThoAdmired  ...
# likes                                                     6  ...
# content   sounds good👍🏻 thank you!\ni remember on my rea...  ...
# date                                                Dec '19  ...
#
#                                                      363  \
# title     Best Byte Loop Contest Top Ten! #LoopForGinger
# catagory                            Community Happenings
# name                                                 hnt
# likes                                                  1
# content                Cast my vote! Good luck everyone
# date                                                  2d
#
#                                                      364  \
# title     Best Byte Loop Contest Top Ten! #LoopForGinger
# catagory                            Community Happenings
# name                                         snapbackdad
# likes                                                  2
# content                               So hard to choose
# date                                                  2d
#
#                                                         365  \
# title        Best Byte Loop Contest Top Ten! #LoopForGinger
# catagory                               Community Happenings
# name                                             The_Ginger
# likes                                                    28
# content   Hello Bytonians!!!\nBefore the list I want to ...
# date                                                     2d
#
#                                                         366  \
# title        Best Byte Loop Contest Top Ten! #LoopForGinger
# catagory                               Community Happenings
# name                                             The_Ginger
# likes                                                     7
# content   Oy vey you’re telling me. Was just telling @ca...
# date                                                     2d
#
#                                                         367  \
# title              Feeling silly… I still can’t use sounds?
# catagory                                 General Discussion
# name                                                   p0rk
# likes                                                     1
# content   I heard that it’s out on android, but I still ...
# date                                                    21h
#
#                                                368  \
# title     Feeling silly… I still can’t use sounds?
# catagory                        General Discussion
# name                                           moj
# likes
# content       me neither!! would love to find out.
# date                                           20h
#
#                                                369  \
# title     Feeling silly… I still can’t use sounds?
# catagory                        General Discussion
# name                          ryanmccarleyLicensed
# likes                                            1
# content            are you using the android beta?
# date                                           20h
#
#                                                         370  \
# title              Feeling silly… I still can’t use sounds?
# catagory                                 General Discussion
# name                                   ryanmccarleyLicensed
# likes
# content   i honestly fell asleep, but quoted are android...
# date                                                    16h
#
#                                                         371  \
# title              Feeling silly… I still can’t use sounds?
# catagory                                 General Discussion
# name                                                   p0rk
# likes                                                     1
# content   I heard that it’s out on android, but I still ...
# date                                                    21h
#
#                                                         372
# title              Feeling silly… I still can’t use sounds?
# catagory                                 General Discussion
# name                                                   p0rk
# likes                                                     1
# content   Oh, is it on beta only still for android? that...
# date                                                    20h
#
# [6 rows x 373 columns]
